# %%
# tutorial: http://stanford.edu/~mgorkove/cgi-bin/rpython_tutorials/Using_Python_to_Extract_Tables_From_PDFs.php
import requests

# get apikey from https://pdftables.com/
apiKey = "3bxr701xf0c1"

def pdfToTable(PDFfilename, apiKey, fileExt, downloadDir):
    fileData = (PDFfilename, open(PDFfilename, 'rb'))
    files = {'f': fileData}
    postUrl = "https://pdftables.com/api?key={0}&format={1}".format(apiKey, fileExt)
    response = requests.post(postUrl, files=files)
    response.raise_for_status()
    with open(downloadDir, "wb") as f:
        f.write(response.content)

# %%
# read the pdf and save it in csv
pdfToTable(PDFfilename, apiKey, fileExt = "csv", 
           downloadDir = "career_launch_co.csv")

# %%
import pandas as pd
data = pd.read_csv("career_launch_co.csv")
data.head()
# Out:
#       Wealthfront’s Career-                               Unnamed: 1
# 0  Launching Companies List                                      NaN
# 1              2017 EDITION                                      NaN
# 2                         A                                      NaN
# 3            Act-On So*ware  Cloud-based integrated markeDng plaEorm
# 4              Portland, OR                                      NaN

# %%
# list column names
list(data)

# rename columns
data.columns = ["Company", "Business"]

# %%
# remove length == 1 in 'Company' column
data = data[data['Company'].map(
    lambda x: len(x) if isinstance(x, str) else 0) != 1]

# %%
# remove first and second rows
data = data.drop(data.index[[0, 1]])

# %%
data.head(10)
# Out:
#              Company                                 Business
# 0     Act-On So*ware  Cloud-based integrated markeDng plaEorm
# 1       Portland, OR                                      NaN
# 2  Affirmed Networks                  Mobile network soluDons
# 3         Boston, MA                                      NaN
# 4        Alien Vault                                      NaN
# 5                NaN                Threat management plaEorm
# 6      San Mateo, CA                                      NaN
# 7            Anaplan  Financial planning and modeling soHware
# 8  San Francisco, CA                                      NaN
# 9          App Annie           Business intelligence soluDons

# %%
# drop rows contain "Wealthfront" in the "company" column
data = data[~data["Company"].str.contains("Wealthfront", na=False, regex=True)]

# %%
# tidy up columns
# issue1: the company column has both a company name and a location
# issue2: the business column has company descriptions split into two rows sometimes
# issue3: we need a location column. This should be referred from the company col

# strategy: consolidate all info in the columns that have the location info
# keep company info and business info in varibles: company and business
# when iterating each row

import re

data['Location'] = "NA"

company = ""
business = ""
for index, row in data.iterrows():
    
    if re.match(r'.+, \w\w', str(row["Company"])):
        row["Location"] = row["Company"]
        row["Company"] = company
        row["Business"] = business
        
        # reset
        business = ""
        company = ""

    elif isinstance(row["Company"], str):
        company = row["Company"]
        
        if isinstance(row["Business"], str):
            business = row["Business"] + business
    
            
    else: # NaN column
        if isinstance(row["Business"], str):
            business = row["Business"] + business

# %%
data.head(20)
# Out:
#                 Company                                           Business  \
# 0        Act-On So*ware            Cloud-based integrated markeDng plaEorm
# 1        Act-On So*ware            Cloud-based integrated markeDng plaEorm
# 2     Affirmed Networks                            Mobile network soluDons
# 3     Affirmed Networks                            Mobile network soluDons
# 4           Alien Vault                                                NaN
# 5                   NaN                          Threat management plaEorm
# 6           Alien Vault                          Threat management plaEorm
# 7               Anaplan            Financial planning and modeling soHware
# 8               Anaplan            Financial planning and modeling soHware
# 9             App Annie                     Business intelligence soluDons
# 10            App Annie                     Business intelligence soluDons
# 11          AppDynamics     ApplicaDon performance management soluDons for
# 12          AppDynamics     ApplicaDon performance management soluDons for
# 13             Automa<c  Content management plaEorm for blogs and websites
# 14             Automa<c  Content management plaEorm for blogs and websites
# 15              Avalara                      Sales tax compliance soluDons
# 16              Avalara                      Sales tax compliance soluDons
# 17                 Avvo         Legal marketplace, directory, and quesDon-
# 18                 Avvo         Legal marketplace, directory, and quesDon-
# 19  Big Switch Networks                            SDN white box switching
#
#              Location
# 0                  NA
# 1        Portland, OR
# 2                  NA
# 3          Boston, MA
# 4                  NA
# 5                  NA
# 6       San Mateo, CA
# 7                  NA
# 8   San Francisco, CA
# 9                  NA
# 10  San Francisco, CA
# 11                 NA
# 12  San Francisco, CA
# 13                 NA
# 14  San Francisco, CA
# 15                 NA
# 16         SeaAle, WA
# 17                 NA
# 18         SeaAle, WA
# 19                 NA

# %%
data = data[data["Location"] != "NA"]

# %%
# reset index
data = data.reset_index(drop=True)
data
# Out:
#                  Company                                           Business  \
# 0         Act-On So*ware            Cloud-based integrated markeDng plaEorm
# 1      Affirmed Networks                            Mobile network soluDons
# 2            Alien Vault                          Threat management plaEorm
# 3                Anaplan            Financial planning and modeling soHware
# 4              App Annie                     Business intelligence soluDons
# 5            AppDynamics     ApplicaDon performance management soluDons for
# 6               Automa<c  Content management plaEorm for blogs and websites
# 7                Avalara                      Sales tax compliance soluDons
# 8                   Avvo         Legal marketplace, directory, and quesDon-
# 9    Big Switch Networks                            SDN white box switching
# 10            Blue Apron                   Grocery delivery service company
# 11    Blue Jeans Network                        Video conferencing services
# 12               Bonobos                   E-commerce driven clothing brand
# 13              Buzzfeed                      Social news and entertainment
# 14              Carbon3D                                   3D manufacturing
# 15          Carbon Black                       Endpoint and server security
# 16            Chartboost  PlaIorm for game developers to market their pr...
# 17                Checkr                     Professional background checks
# 18                Clever                 PlaIorm for extracJng student data
# 19             CloudBees                       Con.nuous deployment so7ware
# 20            Cloudflare    Content delivery network and distributed domain
# 21         Clover Health                                   Health insurance
# 22        Code42 So4ware       Management, backup, storage and protec.on of
# 23             Couchbase                                     NoSQL database
# 24           CrowdStrike                      Threat analysis and preven.on
# 25               Datadog                       Monitoring of cloud services
# 26              DataStax  Distributed database technology build on Cassa...
# 27                  Deem                              Commerce-as-a-service
# 28               Delphix  So7ware to provision, manage, and refresh data...
# 29          DigitalOcean                Cloud hos.ng service for developers
# ..                   ...                                                ...
# 103             SendGrid      Cloud-based enterprise email delivery service
# 104  Silver Peak Systems                        SoFware defined WAN devices
# 105             Security                     Wireless home security systems
# 106           Simplivity                          IT infrastructure plaKorm
# 107   Slack Technologies                    Enterprise communica>on soFware
# 108     Skyhigh Networks  Security for shadow and securely enable sanc>o...
# 109                 SoFi                           Student loan marketplace
# 110           Soundcloud     Online audio distribu>on plaKorm for musicians
# 111          Squarespace           Consumer focused online publishing tools
# 112            S>tch Fix                           Personal styling plaGorm
# 113               Stripe       APIs and tools enabling businesses to accept
# 114           Sumo Logic            Cloud-based log management and analy:cs
# 115               Tanium  Enterprise security and systems management sol...
# 116            Tastemade                     Online food oriented des:na:on
# 117            TeeSpring                 Commerce plaGorm for entrepreneurs
# 118             Security  enterprise networksUnified security monitoring...
# 119        Think Finance  Online financial products for underbanked cons...
# 120         Thought Spot  Rela:onal search engine designed for data anal...
# 121              ThredUp                            Online consignment shop
# 122   Thrive Marketplace                       Online healthy food retailer
# 123            Thumbtack       Online marketplace for home-related services
# 124                 Turo                     Car sharing rental marketplace
# 125       UserTes(ng.com                                 Web tes;ng service
# 126            Vox Media       Online publisher focused on sports, personal
# 127                 VSCO                         Photography apps and tools
# 128         Warby Parker                            Online eyewear retailer
# 129               Weebly             Website and online store crea;on tools
# 130                 Wish                            Mobile commerce plaGorm
# 131             YapStone        Electronic payments for online marketplaces
# 132              ZScaler                  Cloud-delivered security services
#
#               Location
# 0         Portland, OR
# 1           Boston, MA
# 2        San Mateo, CA
# 3    San Francisco, CA
# 4    San Francisco, CA
# 5    San Francisco, CA
# 6    San Francisco, CA
# 7           SeaAle, WA
# 8           SeaAle, WA
# 9      Santa Clara, CA
# 10        New York, NY
# 11   Mountain View, CA
# 12        New York, NY
# 13        New York, NY
# 14    Redwood City, CA
# 15       Cambridge, MA
# 16   San Francisco, CA
# 17   San Francisco, CA
# 18   San Francisco, CA
# 19   San Francisco, CA
# 20   San Francisco, CA
# 21   San Francisco, CA
# 22     Minneapolis, MN
# 23   Mountain View, CA
# 24          Irvine, CA
# 25        New York, NY
# 26     Santa Clara, CA
# 27   San Francisco, CA
# 28   San Francisco, CA
# 29        New York, NY
# ..                 ...
# 103         Denver, CO
# 104    Santa Clara, CA
# 105         Boston, MA
# 106         Boston, MA
# 107  San Francisco, CA
# 108       Campbell, CA
# 109  San Francisco, CA
# 110  San Francisco, CA
# 111       New York, NY
# 112  San Francisco, CA
# 113  San Francsico, CA
# 114   Redwood City, CA
# 115     Emeryville, CA
# 116   Santa Monica, CA
# 117  San Francisco, CA
# 118       Bal:more, MD
# 119         Dallas, TX
# 120      Palo Alto, CA
# 121  San Francisco, CA
# 122    Los Angeles, CA
# 123  San Francisco, CA
# 124  San Francsico, CA
# 125  San Francisco, CA
# 126     Washington, DC
# 127        Oakland, CA
# 128       New York, NY
# 129  San Francisco, CA
# 130  San Francisco, CA
# 131   Walnut Creek, CA
# 132       San Jose, CA
#
# [133 rows x 3 columns]

# %%
data.to_csv("cleand_career_launch_co.csv", encoding='utf-8')
